# %% [markdown]
# # Dashboard Example
#
# The following notebook contains an example of a simple use case of dashboards for exploring a dataset or adding interactivity on reporting.
#
# For a cleaner experience the IPy notebook only contains the minimal code necessary to render the dashboard.
#
# The dashboard is constructed in two separate pieces (small projects can be easily done within one, but it best to separate functionality from the actual point-and-click pieces):
#
# * Dashboard functionality in [`functionality.py`](https://mradmrglabedc01.svr.us.jpmchase.net:19231/user/r559042/edit/personal/r559042/dashboards/staticDashboard/functionality.py): Data functionality and plotters
# * Dashboard creation [`gui.py`](https://mradmrglabedc01.svr.us.jpmchase.net:19231/user/r559042/edit/personal/r559042/dashboards/staticDashboard/gui.py): Creation of the actual dashboard

# %%
from IPython.display import display
from staticDashboard import gui

# %%
display(gui.dashboard)
